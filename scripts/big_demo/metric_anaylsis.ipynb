# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from concept_benchmark.paths import results_dir

demo_results_dir = results_dir / "big_demo"
sudoku_results = "conceptual_safeguards_sudoku.csv"
robot_results = "score_intervention_robot.csv"

# %%
sudoku_df = pd.read_csv(demo_results_dir / sudoku_results)
robot_df = pd.read_csv(demo_results_dir / robot_results)

# %%
coverage = sudoku_df[sudoku_df['metric'].str.contains('coverage')]
coverage['type'] = coverage['metric'].str.split('_').str[1]
# Out:
# /tmp/ipykernel_546/1252860592.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coverage['type'] = coverage['metric'].str.split('_').str[1]

# %%
coverage[(coverage['tau'] == 0.05) & (coverage['split'] == 'test') & (coverage['type'] == 'before')].tail(20)
# Out:
#                    strategy           metric  value split data_name data_type  \
# 1705  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1729  conceptual_safeguards  coverage_before  0.927  test    sudoku   tabular
# 1753  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1777  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1801  conceptual_safeguards  coverage_before  0.989  test    sudoku   tabular
# 1825  conceptual_safeguards  coverage_before  0.989  test    sudoku   tabular
# 1849  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1873  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1897  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1921  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# 1945  conceptual_safeguards  coverage_before  1.000  test    sudoku   tabular
# ...

# %%
selective_acc = sudoku_df[sudoku_df['metric'].str.contains('selective')]
selective_acc['type'] = selective_acc['metric'].str.split('_').str[-1]
# Out:
# /tmp/ipykernel_546/861983395.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selective_acc['type'] = selective_acc['metric'].str.split('_').str[-1]

# %%
selective_acc[(selective_acc['tau'] == 0.05) & (selective_acc['split'] == 'test') & (selective_acc['concept_noise'] > 0.1)]
# Out:
#                    strategy                metric     value split data_name  \
# 936   conceptual_safeguards  selective_acc_before  0.979079  test    sudoku
# 938   conceptual_safeguards   selective_acc_after  0.989879  test    sudoku
# 960   conceptual_safeguards  selective_acc_before  0.792703  test    sudoku
# 962   conceptual_safeguards   selective_acc_after  0.875000  test    sudoku
# 984   conceptual_safeguards  selective_acc_before  0.796902  test    sudoku
# ...                     ...                   ...       ...   ...       ...
# 2114  conceptual_safeguards   selective_acc_after  0.500000  test    sudoku
# 2136  conceptual_safeguards  selective_acc_before  0.500000  test    sudoku
# 2138  conceptual_safeguards   selective_acc_after  0.500000  test    sudoku
# 2160  conceptual_safeguards  selective_acc_before  0.502008  test    sudoku
# 2162  conceptual_safeguards   selective_acc_after  0.504000  test    sudoku
#
# ...

# %%
sudoku_df[(sudoku_df['tau'] == 0.05) & (sudoku_df['split'] == 'test') & (sudoku_df['concept_noise'] > 0.1)]
# Out:
#                    strategy                metric     value split data_name  \
# 936   conceptual_safeguards  selective_acc_before  0.979079  test    sudoku
# 937   conceptual_safeguards       coverage_before  0.478000  test    sudoku
# 938   conceptual_safeguards   selective_acc_after  0.989879  test    sudoku
# 939   conceptual_safeguards        coverage_after  0.988000  test    sudoku
# 960   conceptual_safeguards  selective_acc_before  0.792703  test    sudoku
# ...                     ...                   ...       ...   ...       ...
# 2139  conceptual_safeguards        coverage_after  1.000000  test    sudoku
# 2160  conceptual_safeguards  selective_acc_before  0.502008  test    sudoku
# 2161  conceptual_safeguards       coverage_before  0.996000  test    sudoku
# 2162  conceptual_safeguards   selective_acc_after  0.504000  test    sudoku
# 2163  conceptual_safeguards        coverage_after  1.000000  test    sudoku
#
# ...

# %%
sudoku_df[(sudoku_df['concept_noise'] == 0.0) & (sudoku_df['split'] == 'test') & (sudoku_df['concept_missing'] == 0.3)]
# Out:
#                   strategy                metric     value split data_name  \
# 292  conceptual_safeguards  selective_acc_before  0.995511  test    sudoku
# 293  conceptual_safeguards       coverage_before  0.891000  test    sudoku
# 294  conceptual_safeguards   selective_acc_after  0.995803  test    sudoku
# 295  conceptual_safeguards        coverage_after  0.953000  test    sudoku
# 300  conceptual_safeguards  selective_acc_before  0.991543  test    sudoku
# 301  conceptual_safeguards       coverage_before  0.946000  test    sudoku
# 302  conceptual_safeguards   selective_acc_after  0.991820  test    sudoku
# 303  conceptual_safeguards        coverage_after  0.978000  test    sudoku
# 308  conceptual_safeguards  selective_acc_before  0.987539  test    sudoku
# 309  conceptual_safeguards       coverage_before  0.963000  test    sudoku
# 310  conceptual_safeguards   selective_acc_after  0.987854  test    sudoku
# ...
